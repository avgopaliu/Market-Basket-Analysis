# %% [markdown]
# #### Importing necessary libraries

# %%
import numpy as np
import pandas as pd 
import os
import zipfile
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Association Rules

# %%
order_final = pd.read_csv('order_final.csv')

# %%
order_final.head()
# Out:
#    Unnamed: 0  order_id  product_id  add_to_cart_order  reordered  \
# 0           0         1       49302                  1          1
# 1           1         1       11109                  2          1
# 2           2         1       10246                  3          0
# 3           3         1       49683                  4          0
# 4           4         1       43633                  5          1
#
#                                     product_name  aisle_id  department_id  \
# 0                               Bulgarian Yogurt       120             16
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                          Organic Celery Hearts        83              4
# 3                                 Cucumber Kirby        83              4
# 4           Lightly Smoked Sardines in Olive Oil        95             15
#
#                   aisle    department  ...  product_ordered_count  \
# 0                yogurt    dairy eggs  ...                      8
# 1  other creams cheeses    dairy eggs  ...                    144
# 2      fresh vegetables       produce  ...                   1062
# 3      fresh vegetables       produce  ...                   2413
# 4   canned meat seafood  canned goods  ...                     24
#
#   product_reordered_count  product_reorder_ratio  time_btwn_next_order  \
# 0                       7               0.875000                   9.0
# 1                     107               0.743056                   9.0
# 2                     569               0.535782                   9.0
# 3                    1709               0.708247                   9.0
# 4                      10               0.416667                   9.0
#
#    department_ordered_count  department_reordered_count  \
# 0                    217051                      146502
# 1                    217051                      146502
# 2                    409087                      271886
# 3                    409087                      271886
# 4                     46799                       22782
#
#    department_reorder_ratio  aisle_ordered_count  aisle_reordered_count  \
# 0                  0.674966                55240                  37939
# 1                  0.674966                12820                   7493
# 2                  0.664617               150609                  91368
# 3                  0.664617               150609                  91368
# 4                  0.486805                 3241                   1644
#
#    aisle_reorder_ratio
# 0             0.686803
# 1             0.584477
# 2             0.606657
# 3             0.606657
# 4             0.507251
#
# [5 rows x 27 columns]

# %%
order_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Unnamed: 0                  1384617 non-null  int64
#  1   order_id                    1384617 non-null  int64
#  2   product_id                  1384617 non-null  int64
#  3   add_to_cart_order           1384617 non-null  int64
#  4   reordered                   1384617 non-null  int64
#  5   product_name                1384617 non-null  object
#  6   aisle_id                    1384617 non-null  int64
#  7   department_id               1384617 non-null  int64
#  8   aisle                       1384617 non-null  object
#  9   department                  1384617 non-null  object
#  10  user_id                     1384617 non-null  int64
#  11  eval_set                    1384617 non-null  object
#  12  order_number                1384617 non-null  int64
#  13  order_dow                   1384617 non-null  int64
#  14  order_hour_of_day           1384617 non-null  int64
#  15  days_since_prior_order      1384617 non-null  float64
#  16  count                       1384617 non-null  int64
#  17  product_ordered_count       1384617 non-null  int64
#  18  product_reordered_count     1384617 non-null  int64
#  19  product_reorder_ratio       1384617 non-null  float64
#  20  time_btwn_next_order        1384617 non-null  float64
#  21  department_ordered_count    1384617 non-null  int64
#  22  department_reordered_count  1384617 non-null  int64
#  23  department_reorder_ratio    1384617 non-null  float64
#  24  aisle_ordered_count         1384617 non-null  int64
#  25  aisle_reordered_count       1384617 non-null  int64
#  26  aisle_reorder_ratio         1384617 non-null  float64
# dtypes: float64(5), int64(18), object(4)
# memory usage: 285.2+ MB

# %%
order_final.shape
# Out:
# (1384617, 27)

# %% [markdown]
# ## Creating Basket for the products

# %%
order_final = order_final.drop(columns = ['Unnamed: 0'])

# %%
# Reducing the data set due to constant memory issues
order_final = order_final[:10000]

# %%
#Taking the count of product ordered
product_orderd = order_final.groupby(by=['product_id'],as_index=False).agg({'order_id':'count'})
product_orderd.head()
# Out:
#    product_id  order_id
# 0           1         1
# 1          10         2
# 2          23         1
# 3          25         1
# 4          34         2

# %%
#Renaming and sorting the df
product_orderd = product_orderd.rename(columns={'order_id': 'times_ordered'})
product_orderd = product_orderd.sort_values('times_ordered', ascending = False)
product_orderd.head(2)
# Out:
#       product_id  times_ordered
# 2316       24852            124
# 1962       21137             98

# %%
#Combining the products ordered with data in order_final data based on product_id
product_orderd = list(product_orderd.product_id)
product_orderd = order_final[order_final.product_id.isin(product_orderd)]
product_orderd.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1
#
#                                     product_name  aisle_id  department_id  \
# 0                               Bulgarian Yogurt       120             16
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                          Organic Celery Hearts        83              4
# 3                                 Cucumber Kirby        83              4
# 4           Lightly Smoked Sardines in Olive Oil        95             15
#
#                   aisle    department  user_id  ... product_ordered_count  \
# 0                yogurt    dairy eggs   112108  ...                     8
# 1  other creams cheeses    dairy eggs   112108  ...                   144
# 2      fresh vegetables       produce   112108  ...                  1062
# 3      fresh vegetables       produce   112108  ...                  2413
# 4   canned meat seafood  canned goods   112108  ...                    24
#
#    product_reordered_count  product_reorder_ratio  time_btwn_next_order  \
# 0                        7               0.875000                   9.0
# 1                      107               0.743056                   9.0
# 2                      569               0.535782                   9.0
# 3                     1709               0.708247                   9.0
# 4                       10               0.416667                   9.0
#
#    department_ordered_count  department_reordered_count  \
# 0                    217051                      146502
# 1                    217051                      146502
# 2                    409087                      271886
# 3                    409087                      271886
# 4                     46799                       22782
#
#    department_reorder_ratio  aisle_ordered_count  aisle_reordered_count  \
# 0                  0.674966                55240                  37939
# 1                  0.674966                12820                   7493
# 2                  0.664617               150609                  91368
# 3                  0.664617               150609                  91368
# 4                  0.486805                 3241                   1644
#
#    aisle_reorder_ratio
# 0             0.686803
# 1             0.584477
# 2             0.606657
# 3             0.606657
# 4             0.507251
#
# [5 rows x 26 columns]

# %%
product_orderd.shape
# Out:
# (10000, 26)

# %%
#Creating a pivot table using order_id and product_name
basket_product = product_orderd.pivot_table(columns='product_name', values='reordered', index='order_id').fillna(0)

# %%
basket_product.shape
# Out:
# (939, 4660)

# %%
basket_product.head()
# Out:
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 1                                             0.0
# 36                                            0.0
# 38                                            0.0
# 96                                            0.0
# 98                                            0.0
#
# product_name  0% Fat Superfruits Greek Yogurt  0% Greek Strained Yogurt  \
# order_id
# 1                                         0.0                       0.0
# 36                                        0.0                       0.0
# 38                                        0.0                       0.0
# 96                                        0.0                       0.0
# 98                                        0.0                       0.0
#
# product_name  1 Apple + 1 Pear Fruit Bar  1 Liter  1 Ply Paper Towels  \
# order_id
# 1                                    0.0      0.0                 0.0
# 36                                   0.0      0.0                 0.0
# 38                                   0.0      0.0                 0.0
# 96                                   0.0      0.0                 0.0
# 98                                   0.0      0.0                 0.0
#
# product_name  1% Chocolate Milk  1% Low Fat Milk  1% Lowfat Milk  \
# order_id
# 1                           0.0              0.0             0.0
# 36                          0.0              0.0             0.0
# 38                          0.0              0.0             0.0
# 96                          0.0              0.0             0.0
# 98                          0.0              0.0             0.0
#
# product_name  1,000 mg Vitamin C Lemon-Lime Flavored Fizzy Drink Mix - 30 PK  \
# order_id
# 1                                                           0.0
# 36                                                          0.0
# 38                                                          0.0
# 96                                                          0.0
# 98                                                          0.0
#
# product_name  ...  Zero Coke Soda Mini Bottles  Zero Cola  \
# order_id      ...
# 1             ...                          0.0        0.0
# 36            ...                          0.0        0.0
# 38            ...                          0.0        0.0
# 96            ...                          0.0        0.0
# 98            ...                          0.0        0.0
#
# product_name  Zero Go-Go Mixed Berry Vitamin Water  Zero Soda  \
# order_id
# 1                                              0.0        0.0
# 36                                             0.0        0.0
# 38                                             0.0        0.0
# 96                                             0.0        0.0
# 98                                             0.0        0.0
#
# product_name  Zero Strawberry Lemon  Zucchini Squash  \
# order_id
# 1                               0.0              0.0
# 36                              0.0              0.0
# 38                              0.0              0.0
# 96                              0.0              0.0
# 98                              0.0              0.0
#
# product_name  of Norwich Original English Mustard Powder Double Superfine  \
# order_id
# 1                                                           0.0
# 36                                                          0.0
# 38                                                          0.0
# 96                                                          0.0
# 98                                                          0.0
#
# product_name  smartwater® Electrolyte Enhanced Water  \
# order_id
# 1                                                0.0
# 36                                               0.0
# 38                                               0.0
# 96                                               0.0
# 98                                               0.0
#
# product_name  vitaminwater® XXX Acai Blueberry Pomegranate  \
# order_id
# 1                                                      0.0
# 36                                                     0.0
# 38                                                     0.0
# 96                                                     0.0
# 98                                                     0.0
#
# product_name  with Crispy Almonds Cereal
# order_id
# 1                                    0.0
# 36                                   0.0
# 38                                   0.0
# 96                                   0.0
# 98                                   0.0
#
# [5 rows x 4660 columns]

# %%
## Performing One Hot encoding on the data

def one_hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1
    
basket_encoded = basket_product.applymap(one_hot_encode)
basket_product = basket_encoded

# %%
basket_product.head()
# Out:
# product_name  0% Fat Organic Greek Vanilla Yogurt  \
# order_id
# 1                                               0
# 36                                              0
# 38                                              0
# 96                                              0
# 98                                              0
#
# product_name  0% Fat Superfruits Greek Yogurt  0% Greek Strained Yogurt  \
# order_id
# 1                                           0                         0
# 36                                          0                         0
# 38                                          0                         0
# 96                                          0                         0
# 98                                          0                         0
#
# product_name  1 Apple + 1 Pear Fruit Bar  1 Liter  1 Ply Paper Towels  \
# order_id
# 1                                      0        0                   0
# 36                                     0        0                   0
# 38                                     0        0                   0
# 96                                     0        0                   0
# 98                                     0        0                   0
#
# product_name  1% Chocolate Milk  1% Low Fat Milk  1% Lowfat Milk  \
# order_id
# 1                             0                0               0
# 36                            0                0               0
# 38                            0                0               0
# 96                            0                0               0
# 98                            0                0               0
#
# product_name  1,000 mg Vitamin C Lemon-Lime Flavored Fizzy Drink Mix - 30 PK  \
# order_id
# 1                                                             0
# 36                                                            0
# 38                                                            0
# 96                                                            0
# 98                                                            0
#
# product_name  ...  Zero Coke Soda Mini Bottles  Zero Cola  \
# order_id      ...
# 1             ...                            0          0
# 36            ...                            0          0
# 38            ...                            0          0
# 96            ...                            0          0
# 98            ...                            0          0
#
# product_name  Zero Go-Go Mixed Berry Vitamin Water  Zero Soda  \
# order_id
# 1                                                0          0
# 36                                               0          0
# 38                                               0          0
# 96                                               0          0
# 98                                               0          0
#
# product_name  Zero Strawberry Lemon  Zucchini Squash  \
# order_id
# 1                                 0                0
# 36                                0                0
# 38                                0                0
# 96                                0                0
# 98                                0                0
#
# product_name  of Norwich Original English Mustard Powder Double Superfine  \
# order_id
# 1                                                             0
# 36                                                            0
# 38                                                            0
# 96                                                            0
# 98                                                            0
#
# product_name  smartwater® Electrolyte Enhanced Water  \
# order_id
# 1                                                  0
# 36                                                 0
# 38                                                 0
# 96                                                 0
# 98                                                 0
#
# product_name  vitaminwater® XXX Acai Blueberry Pomegranate  \
# order_id
# 1                                                        0
# 36                                                       0
# 38                                                       0
# 96                                                       0
# 98                                                       0
#
# product_name  with Crispy Almonds Cereal
# order_id
# 1                                      0
# 36                                     0
# 38                                     0
# 96                                     0
# 98                                     0
#
# [5 rows x 4660 columns]

# %% [markdown]
# ### Applying Association Rules on the basket

# %%
# Building the model using apriori with min_support=0.0075
freq_basket = apriori(basket_product, min_support = 0.008, use_colnames = True, verbose = 1)
freq_basket.shape
# Out:
# Processing 327 combinations | Sampling itemset size 3
# (112, 2)

# %%
freq_basket.head()
# Out:
#     support                           itemsets
# 0  0.009585  (100% Lactose Free Fat Free Milk)
# 1  0.015974           (100% Whole Wheat Bread)
# 2  0.014909         (Apple Honeycrisp Organic)
# 3  0.013845                        (Asparagus)
# 4  0.087327           (Bag of Organic Bananas)

# %%
freq_basket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   support   112 non-null    float64
#  1   itemsets  112 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 1.9+ KB

# %%
product_ar = association_rules(freq_basket, metric ="lift", min_threshold = 1)

# %%
product_ar
# Out:
#                                antecedents  \
# 0                            (Large Lemon)
# 1                 (Bag of Organic Bananas)
# 2                   (Organic Baby Spinach)
# 3                 (Bag of Organic Bananas)
# 4                   (Organic Hass Avocado)
# 5                 (Bag of Organic Bananas)
# 6                          (Organic Lemon)
# 7                 (Bag of Organic Bananas)
# 8                    (Organic Raspberries)
# 9                 (Bag of Organic Bananas)
# 10                (Bag of Organic Bananas)
# 11                  (Organic Strawberries)
# 12                    (Organic Whole Milk)
# 13                (Bag of Organic Bananas)
# 14                  (Organic Baby Spinach)
# 15                                (Banana)
# 16                                (Banana)
# 17                  (Organic Strawberries)
# 18                           (Large Lemon)
# 19                                 (Limes)
# 20                       (Organic Avocado)
# 21                           (Large Lemon)
# 22                           (Large Lemon)
# 23                  (Organic Baby Spinach)
# 24                  (Organic Hass Avocado)
# 25                           (Large Lemon)
# 26                       (Organic Avocado)
